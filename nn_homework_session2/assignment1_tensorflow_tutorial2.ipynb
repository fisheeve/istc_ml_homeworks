# %% [markdown]
# # MNIST master
#
# For a demo we shall solve the same digit recognition problem, but at a different scale
# * images are now 28x28
# * 10 different digits
# * 50k samples

# %% [markdown]
# Before doing this homework, read some code examples written in tensorflow. There is a good repository with code examples: https://github.com/aymericdamien/TensorFlow-Examples. As we already know, we need many samples to learn :)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf

# %%
from mnist import load_dataset
X_train,y_train,X_val,y_val,X_test,y_test = load_dataset()

print(X_train.shape,y_train.shape)
# Out:
# (50000, 1, 28, 28) (50000,)

# %%
X_train.shape
# Out:
# (50000, 1, 28, 28)

# %%
plt.imshow(-X_train[20, 0], cmap="jet")
y_train[20]
# Out:
# 4

# %%
#defining placeholders for input and target
input_X = tf.placeholder(tf.float32, shape=[None, 1, 28, 28], 
                         name="X")
target_y = tf.placeholder(tf.int32, shape=[None], 
                          name="target_Y_integer")

# %% [markdown]
# Defining network architecture

# %%
mode=True
# flatten images to (batch_size x 728) matrix
input_X_reshaped = tf.reshape(input_X, shape=[-1, 1*28*28], 
                              name="reshape_X")


h1 = tf.layers.conv2d(tf.reshape(input_X, shape=[-1,28,28,1]), filters=32, kernel_size=[5,5], 
                     padding="same", activation=tf.nn.relu)
print(np.shape(h1))

h2 = tf.layers.max_pooling2d(h1, pool_size=2, strides=2)

print(np.shape(h2))


h3 = tf.layers.conv2d(h2, filters=64, kernel_size = [5,5],
                     padding='same', activation=tf.nn.relu)
print(np.shape(h3))

h4 = tf.layers.max_pooling2d(h3, pool_size=2, strides=2)

print(np.shape(h4))

h5 = tf.layers.dense(tf.reshape(h4, shape=[-1,3136]), units=1024, activation=None)

h6 = tf.layers.dropout(h5, rate=0.4, training=mode)

h7 = tf.nn.relu(h6)

# 10 neurons (1 for each digit).
# This predicts scores for the classes
l2 = tf.layers.dense(h7, units=10, activation=None)


# We use softmax nonlinearity to make probabilities add up to 1
l_out = tf.nn.softmax(l2)

# Prediction
y_predicted = tf.argmax(l2, axis=-1)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0726 12:01:59.398792 140180509525824 deprecation.py:323] From <ipython-input-7-a5078e2faa23>:8: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# W0726 12:01:59.403085 140180509525824 deprecation.py:506] From /home/yeva/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0726 12:01:59.742300 140180509525824 deprecation.py:323] From <ipython-input-7-a5078e2faa23>:11: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# W0726 12:01:59.887702 140180509525824 deprecation.py:323] From <ipython-input-7-a5078e2faa23>:24: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# (?, 28, 28, 32)
# (?, 14, 14, 32)
# (?, 14, 14, 64)
# (?, 7, 7, 64)
# W0726 12:02:00.120347 140180509525824 deprecation.py:323] From <ipython-input-7-a5078e2faa23>:26: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.

# %%
weights = tf.trainable_variables()
weights
# Out:
# [<tf.Variable 'conv2d/kernel:0' shape=(5, 5, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'conv2d_1/kernel:0' shape=(5, 5, 32, 64) dtype=float32_ref>,
#  <tf.Variable 'conv2d_1/bias:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(3136, 1024) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'dense_1/kernel:0' shape=(1024, 10) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(10,) dtype=float32_ref>]

# %% [markdown]
# ### Than you could simply
# * define loss function manually
# * compute error gradient over all weights
# * define updates
# * But that's a whole lot of work and life's short
#   * not to mention life's too short to wait for SGD to converge
#
# Instead, we shall use Tensorflow builtins

# %%
# Mean categorical crossentropy as a loss function
# - similar to logistic loss but for multiclass targets
loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
    labels=target_y, logits=l2, name="softmax_loss"))

# %%
accuracy, update_accuracy = tf.metrics.accuracy(target_y, y_predicted)
tf.local_variables()
# Out:
# [<tf.Variable 'accuracy/total:0' shape=() dtype=float32_ref>,
#  <tf.Variable 'accuracy/count:0' shape=() dtype=float32_ref>]

# %%
optimzer = tf.train.GradientDescentOptimizer(learning_rate=0.09)
train_step = optimzer.minimize(loss)

# %% [markdown]
# ### That's all, now let's train it!
# * We got a lot of data, so it's recommended that you use SGD
# * So let's implement a function that splits the training sample into minibatches

# %%
# An auxilary function that returns mini-batches for neural network training

#Parameters
# inputs - a tensor of images with shape (many, 1, 28, 28), e.g. X_train
# outputs - a vector of answers for corresponding images e.g. Y_train
#batch_size - a single number - the intended size of each batches

def iterate_minibatches(inputs, targets, batchsize):
    assert len(inputs) == len(targets)
    indices = np.arange(len(inputs))
    np.random.shuffle(indices)
    for start_idx in range(0, len(inputs) - batchsize + 1, batchsize):
        excerpt = indices[start_idx:start_idx + batchsize]
        yield inputs[excerpt], targets[excerpt]

# %% [markdown]
# # Training loop

# %% [markdown]
# Model saver.
# <br>
# See more:
# http://cv-tricks.com/tensorflow-tutorial/save-restore-tensorflow-models-quick-complete-tutorial/

# %%
model_path = "./checkpoints/model.ckpt"
saver = tf.train.Saver(max_to_keep=3)

# %%
import time

num_epochs = 100 # amount of passes through the data

batch_size = 50 # number of samples processed at each function call

with tf.Session() as sess:
    # initialize global wariables
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(num_epochs):
        # In each epoch, we do a full pass over the training data:
        train_err = 0
        train_batches = 0
        start_time = time.time()

        sess.run(tf.local_variables_initializer())
        for batch in iterate_minibatches(X_train, y_train,batch_size):
            inputs, targets = batch

            _, train_err_batch, _ = sess.run(
                [train_step, loss, update_accuracy], 
                feed_dict={input_X: inputs, target_y:targets}
            )
            train_err += train_err_batch
            train_batches += 1
        train_acc = sess.run(accuracy)

        # And a full pass over the validation data:
        sess.run(tf.local_variables_initializer())
        for batch in iterate_minibatches(X_val, y_val, batch_size):
            inputs, targets = batch
            sess.run(update_accuracy, feed_dict={input_X: inputs, 
                                                 target_y:targets})
        val_acc = sess.run(accuracy)


        # Then we print the results for this epoch:
        print("Epoch {} of {} took {:.3f}s".format(
            epoch + 1, num_epochs, time.time() - start_time))

        print("  training loss (in-iteration):\t\t{:.6f}".format(train_err / train_batches))
        print("  train accuracy:\t\t{:.2f} %".format(
            train_acc * 100))
        print("  validation accuracy:\t\t{:.2f} %".format(
            val_acc * 100))
        
        # save model
        save_path = saver.save(sess, model_path, global_step=epoch)
        print("  Model saved in file: %s" % save_path)
# Out:
# Epoch 1 of 100 took 59.818s
#   training loss (in-iteration):		0.215904
#   train accuracy:		93.01 %
#   validation accuracy:		97.97 %
#   Model saved in file: ./checkpoints/model.ckpt-0
# Epoch 2 of 100 took 59.373s
#   training loss (in-iteration):		0.066271
#   train accuracy:		97.96 %
#   validation accuracy:		98.39 %
#   Model saved in file: ./checkpoints/model.ckpt-1
# Epoch 3 of 100 took 57.850s
#   training loss (in-iteration):		0.045543
#   train accuracy:		98.59 %
#   validation accuracy:		98.67 %
#   Model saved in file: ./checkpoints/model.ckpt-2
# W0726 12:06:08.730744 140180509525824 deprecation.py:323] From /home/yeva/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Epoch 4 of 100 took 57.903s
#   training loss (in-iteration):		0.036862
#   train accuracy:		98.83 %
#   validation accuracy:		98.69 %
#   Model saved in file: ./checkpoints/model.ckpt-3
# Epoch 5 of 100 took 57.840s
#   training loss (in-iteration):		0.028448
#   train accuracy:		99.10 %
#   validation accuracy:		98.77 %
#   Model saved in file: ./checkpoints/model.ckpt-4
# Epoch 6 of 100 took 57.896s
#   training loss (in-iteration):		0.024189
#   train accuracy:		99.22 %
#   validation accuracy:		98.75 %
#   Model saved in file: ./checkpoints/model.ckpt-5
# Epoch 7 of 100 took 57.742s
#   training loss (in-iteration):		0.019141
#   train accuracy:		99.36 %
#   validation accuracy:		98.80 %
#   Model saved in file: ./checkpoints/model.ckpt-6
# Epoch 8 of 100 took 58.189s
#   training loss (in-iteration):		0.015838
#   train accuracy:		99.47 %
#   validation accuracy:		98.93 %
#   Model saved in file: ./checkpoints/model.ckpt-7
# Epoch 9 of 100 took 59.534s
#   training loss (in-iteration):		0.015435
#   train accuracy:		99.51 %
#   validation accuracy:		98.82 %
#   Model saved in file: ./checkpoints/model.ckpt-8
# Epoch 10 of 100 took 59.924s
#   training loss (in-iteration):		0.012546
#   train accuracy:		99.59 %
#   validation accuracy:		98.90 %
#   Model saved in file: ./checkpoints/model.ckpt-9
# Epoch 11 of 100 took 60.012s
#   training loss (in-iteration):		0.010820
#   train accuracy:		99.63 %
#   validation accuracy:		98.95 %
#   Model saved in file: ./checkpoints/model.ckpt-10
# Epoch 12 of 100 took 60.319s
#   training loss (in-iteration):		0.009988
#   train accuracy:		99.68 %
#   validation accuracy:		98.86 %
#   Model saved in file: ./checkpoints/model.ckpt-11
# Epoch 13 of 100 took 60.443s
#   training loss (in-iteration):		0.008680
#   train accuracy:		99.71 %
#   validation accuracy:		98.96 %
#   Model saved in file: ./checkpoints/model.ckpt-12
# Epoch 14 of 100 took 60.705s
#   training loss (in-iteration):		0.008122
#   train accuracy:		99.72 %
#   validation accuracy:		98.97 %
#   Model saved in file: ./checkpoints/model.ckpt-13
# Epoch 15 of 100 took 60.857s
#   training loss (in-iteration):		0.005676
#   train accuracy:		99.81 %
#   validation accuracy:		99.08 %
#   Model saved in file: ./checkpoints/model.ckpt-14
# Epoch 16 of 100 took 60.953s
#   training loss (in-iteration):		0.004712
#   train accuracy:		99.85 %
#   validation accuracy:		99.09 %
#   Model saved in file: ./checkpoints/model.ckpt-15
# Epoch 17 of 100 took 60.947s
#   training loss (in-iteration):		0.003827
#   train accuracy:		99.89 %
#   validation accuracy:		99.12 %
#   Model saved in file: ./checkpoints/model.ckpt-16
# Epoch 18 of 100 took 61.050s
#   training loss (in-iteration):		0.004401
#   train accuracy:		99.86 %
#   validation accuracy:		99.20 %
#   Model saved in file: ./checkpoints/model.ckpt-17
# Epoch 19 of 100 took 61.058s
#   training loss (in-iteration):		0.004925
#   train accuracy:		99.83 %
#   validation accuracy:		99.14 %
#   Model saved in file: ./checkpoints/model.ckpt-18
# Epoch 20 of 100 took 61.187s
#   training loss (in-iteration):		0.004051
#   train accuracy:		99.88 %
#   validation accuracy:		99.12 %
#   Model saved in file: ./checkpoints/model.ckpt-19
# Epoch 21 of 100 took 61.067s
#   training loss (in-iteration):		0.003363
#   train accuracy:		99.91 %
#   validation accuracy:		99.10 %
#   Model saved in file: ./checkpoints/model.ckpt-20
# Epoch 22 of 100 took 61.152s
#   training loss (in-iteration):		0.003214
#   train accuracy:		99.89 %
#   validation accuracy:		99.10 %
#   Model saved in file: ./checkpoints/model.ckpt-21
# Epoch 23 of 100 took 61.158s
#   training loss (in-iteration):		0.002448
#   train accuracy:		99.93 %
#   validation accuracy:		99.13 %
#   Model saved in file: ./checkpoints/model.ckpt-22
# Epoch 24 of 100 took 61.379s
#   training loss (in-iteration):		0.002114
#   train accuracy:		99.94 %
#   validation accuracy:		99.08 %
#   Model saved in file: ./checkpoints/model.ckpt-23
# Epoch 25 of 100 took 61.029s
#   training loss (in-iteration):		0.002372
#   train accuracy:		99.92 %
#   validation accuracy:		99.10 %
#   Model saved in file: ./checkpoints/model.ckpt-24
# Epoch 26 of 100 took 61.137s
#   training loss (in-iteration):		0.001701
#   train accuracy:		99.95 %
#   validation accuracy:		99.02 %
#   Model saved in file: ./checkpoints/model.ckpt-25
# Epoch 27 of 100 took 61.706s
#   training loss (in-iteration):		0.001964
#   train accuracy:		99.95 %
#   validation accuracy:		98.91 %
#   Model saved in file: ./checkpoints/model.ckpt-26
# Epoch 28 of 100 took 61.646s
#   training loss (in-iteration):		0.002393
#   train accuracy:		99.93 %
#   validation accuracy:		98.81 %
#   Model saved in file: ./checkpoints/model.ckpt-27
# Epoch 29 of 100 took 61.500s
#   training loss (in-iteration):		0.001994
#   train accuracy:		99.94 %
#   validation accuracy:		99.15 %
#   Model saved in file: ./checkpoints/model.ckpt-28
# Epoch 30 of 100 took 61.684s
#   training loss (in-iteration):		0.001398
#   train accuracy:		99.96 %
#   validation accuracy:		99.20 %
#   Model saved in file: ./checkpoints/model.ckpt-29
# Epoch 31 of 100 took 61.390s
#   training loss (in-iteration):		0.001392
#   train accuracy:		99.96 %
#   validation accuracy:		98.98 %
#   Model saved in file: ./checkpoints/model.ckpt-30
# Epoch 32 of 100 took 61.479s
#   training loss (in-iteration):		0.001838
#   train accuracy:		99.95 %
#   validation accuracy:		99.13 %
#   Model saved in file: ./checkpoints/model.ckpt-31
# Epoch 33 of 100 took 61.684s
#   training loss (in-iteration):		0.001541
#   train accuracy:		99.96 %
#   validation accuracy:		99.14 %
#   Model saved in file: ./checkpoints/model.ckpt-32
# Epoch 34 of 100 took 61.789s
#   training loss (in-iteration):		0.001032
#   train accuracy:		99.97 %
#   validation accuracy:		99.16 %
#   Model saved in file: ./checkpoints/model.ckpt-33
# Epoch 35 of 100 took 61.598s
#   training loss (in-iteration):		0.001235
#   train accuracy:		99.97 %
#   validation accuracy:		99.11 %
#   Model saved in file: ./checkpoints/model.ckpt-34
# Epoch 36 of 100 took 61.505s
#   training loss (in-iteration):		0.000972
#   train accuracy:		99.98 %
#   validation accuracy:		99.10 %
#   Model saved in file: ./checkpoints/model.ckpt-35
# Epoch 37 of 100 took 61.534s
#   training loss (in-iteration):		0.000996
#   train accuracy:		99.97 %
#   validation accuracy:		99.01 %
#   Model saved in file: ./checkpoints/model.ckpt-36
# Epoch 38 of 100 took 62.129s
#   training loss (in-iteration):		0.000839
#   train accuracy:		99.97 %
#   validation accuracy:		99.10 %
#   Model saved in file: ./checkpoints/model.ckpt-37
# Epoch 39 of 100 took 61.579s
#   training loss (in-iteration):		0.001031
#   train accuracy:		99.96 %
#   validation accuracy:		99.07 %
#   Model saved in file: ./checkpoints/model.ckpt-38
# Epoch 40 of 100 took 61.888s
#   training loss (in-iteration):		0.001206
#   train accuracy:		99.97 %
#   validation accuracy:		99.13 %
#   Model saved in file: ./checkpoints/model.ckpt-39
# Epoch 41 of 100 took 61.919s
#   training loss (in-iteration):		0.001728
#   train accuracy:		99.94 %
#   validation accuracy:		99.06 %
#   Model saved in file: ./checkpoints/model.ckpt-40
# Epoch 42 of 100 took 61.944s
#   training loss (in-iteration):		0.001311
#   train accuracy:		99.96 %
#   validation accuracy:		99.11 %
#   Model saved in file: ./checkpoints/model.ckpt-41
# Epoch 43 of 100 took 61.779s
#   training loss (in-iteration):		0.001047
#   train accuracy:		99.96 %
#   validation accuracy:		99.13 %
#   Model saved in file: ./checkpoints/model.ckpt-42
# Epoch 44 of 100 took 62.260s
#   training loss (in-iteration):		0.001398
#   train accuracy:		99.96 %
#   validation accuracy:		99.12 %
#   Model saved in file: ./checkpoints/model.ckpt-43
# Epoch 45 of 100 took 61.822s
#   training loss (in-iteration):		0.001096
#   train accuracy:		99.97 %
#   validation accuracy:		99.12 %
#   Model saved in file: ./checkpoints/model.ckpt-44
# Epoch 46 of 100 took 62.183s
#   training loss (in-iteration):		0.000765
#   train accuracy:		99.98 %
#   validation accuracy:		99.10 %
#   Model saved in file: ./checkpoints/model.ckpt-45
# Epoch 47 of 100 took 62.256s
#   training loss (in-iteration):		0.000573
#   train accuracy:		99.99 %
#   validation accuracy:		99.23 %
#   Model saved in file: ./checkpoints/model.ckpt-46
# Epoch 48 of 100 took 61.985s
#   training loss (in-iteration):		0.000288
#   train accuracy:		100.00 %
#   validation accuracy:		99.20 %
#   Model saved in file: ./checkpoints/model.ckpt-47
# Epoch 49 of 100 took 62.135s
#   training loss (in-iteration):		0.000565
#   train accuracy:		99.98 %
#   validation accuracy:		99.14 %
#   Model saved in file: ./checkpoints/model.ckpt-48
# Epoch 50 of 100 took 62.190s
#   training loss (in-iteration):		0.000462
#   train accuracy:		99.99 %
#   validation accuracy:		99.15 %
#   Model saved in file: ./checkpoints/model.ckpt-49
# Epoch 51 of 100 took 62.046s
#   training loss (in-iteration):		0.000865
#   train accuracy:		99.98 %
#   validation accuracy:		99.06 %
#   Model saved in file: ./checkpoints/model.ckpt-50
# Epoch 52 of 100 took 61.854s
#   training loss (in-iteration):		0.000475
#   train accuracy:		99.99 %
#   validation accuracy:		99.14 %
#   Model saved in file: ./checkpoints/model.ckpt-51
# Epoch 53 of 100 took 62.141s
#   training loss (in-iteration):		0.000758
#   train accuracy:		99.98 %
#   validation accuracy:		99.20 %
#   Model saved in file: ./checkpoints/model.ckpt-52
# Epoch 54 of 100 took 62.088s
#   training loss (in-iteration):		0.000504
#   train accuracy:		99.99 %
#   validation accuracy:		99.07 %
#   Model saved in file: ./checkpoints/model.ckpt-53
# Epoch 55 of 100 took 62.082s
#   training loss (in-iteration):		0.000257
#   train accuracy:		100.00 %
#   validation accuracy:		99.27 %
#   Model saved in file: ./checkpoints/model.ckpt-54
# Epoch 56 of 100 took 62.079s
#   training loss (in-iteration):		0.000267
#   train accuracy:		100.00 %
#   validation accuracy:		99.19 %
#   Model saved in file: ./checkpoints/model.ckpt-55
# Epoch 57 of 100 took 62.258s
#   training loss (in-iteration):		0.000453
#   train accuracy:		99.99 %
#   validation accuracy:		99.16 %
#   Model saved in file: ./checkpoints/model.ckpt-56
# Epoch 58 of 100 took 62.096s
#   training loss (in-iteration):		0.000959
#   train accuracy:		99.96 %
#   validation accuracy:		99.06 %
#   Model saved in file: ./checkpoints/model.ckpt-57
# Epoch 59 of 100 took 61.991s
#   training loss (in-iteration):		0.000685
#   train accuracy:		99.98 %
#   validation accuracy:		99.07 %
#   Model saved in file: ./checkpoints/model.ckpt-58
# Epoch 60 of 100 took 62.114s
#   training loss (in-iteration):		0.001248
#   train accuracy:		99.96 %
#   validation accuracy:		99.00 %
#   Model saved in file: ./checkpoints/model.ckpt-59
# Epoch 61 of 100 took 62.256s
#   training loss (in-iteration):		0.000941
#   train accuracy:		99.97 %
#   validation accuracy:		99.14 %
#   Model saved in file: ./checkpoints/model.ckpt-60
# Epoch 62 of 100 took 62.011s
#   training loss (in-iteration):		0.000806
#   train accuracy:		99.98 %
#   validation accuracy:		99.21 %
#   Model saved in file: ./checkpoints/model.ckpt-61
# Epoch 63 of 100 took 62.343s
#   training loss (in-iteration):		0.000278
#   train accuracy:		100.00 %
#   validation accuracy:		99.16 %
#   Model saved in file: ./checkpoints/model.ckpt-62
# Epoch 64 of 100 took 62.120s
#   training loss (in-iteration):		0.000360
#   train accuracy:		99.99 %
#   validation accuracy:		99.18 %
#   Model saved in file: ./checkpoints/model.ckpt-63
# Epoch 65 of 100 took 62.033s
#   training loss (in-iteration):		0.000338
#   train accuracy:		99.99 %
#   validation accuracy:		99.18 %
#   Model saved in file: ./checkpoints/model.ckpt-64
# Epoch 66 of 100 took 62.071s
#   training loss (in-iteration):		0.000345
#   train accuracy:		99.99 %
#   validation accuracy:		99.25 %
#   Model saved in file: ./checkpoints/model.ckpt-65
# Epoch 67 of 100 took 62.240s
#   training loss (in-iteration):		0.000512
#   train accuracy:		99.98 %
#   validation accuracy:		99.20 %
#   Model saved in file: ./checkpoints/model.ckpt-66
# Epoch 68 of 100 took 62.122s
#   training loss (in-iteration):		0.000518
#   train accuracy:		99.98 %
#   validation accuracy:		99.17 %
#   Model saved in file: ./checkpoints/model.ckpt-67
# Epoch 69 of 100 took 61.975s
#   training loss (in-iteration):		0.000225
#   train accuracy:		100.00 %
#   validation accuracy:		99.12 %
#   Model saved in file: ./checkpoints/model.ckpt-68
# Epoch 70 of 100 took 62.155s
#   training loss (in-iteration):		0.000215
#   train accuracy:		100.00 %
#   validation accuracy:		99.16 %
#   Model saved in file: ./checkpoints/model.ckpt-69
# Epoch 71 of 100 took 62.240s
#   training loss (in-iteration):		0.000107
#   train accuracy:		100.00 %
#   validation accuracy:		99.26 %
#   Model saved in file: ./checkpoints/model.ckpt-70
# Epoch 72 of 100 took 61.990s
#   training loss (in-iteration):		0.000165
#   train accuracy:		100.00 %
#   validation accuracy:		99.21 %
#   Model saved in file: ./checkpoints/model.ckpt-71
# Epoch 73 of 100 took 62.265s
#   training loss (in-iteration):		0.000150
#   train accuracy:		100.00 %
#   validation accuracy:		99.19 %
#   Model saved in file: ./checkpoints/model.ckpt-72
# Epoch 74 of 100 took 62.288s
#   training loss (in-iteration):		0.000142
#   train accuracy:		100.00 %
#   validation accuracy:		99.16 %
#   Model saved in file: ./checkpoints/model.ckpt-73
# Epoch 75 of 100 took 61.953s
#   training loss (in-iteration):		0.000115
#   train accuracy:		100.00 %
#   validation accuracy:		99.21 %
#   Model saved in file: ./checkpoints/model.ckpt-74
# Epoch 76 of 100 took 62.100s
#   training loss (in-iteration):		0.000244
#   train accuracy:		99.99 %
#   validation accuracy:		99.20 %
#   Model saved in file: ./checkpoints/model.ckpt-75
# Epoch 77 of 100 took 62.103s
#   training loss (in-iteration):		0.000137
#   train accuracy:		100.00 %
#   validation accuracy:		99.21 %
#   Model saved in file: ./checkpoints/model.ckpt-76
# Epoch 78 of 100 took 62.186s
#   training loss (in-iteration):		0.000272
#   train accuracy:		99.99 %
#   validation accuracy:		99.31 %
#   Model saved in file: ./checkpoints/model.ckpt-77
# Epoch 79 of 100 took 61.819s
#   training loss (in-iteration):		0.000154
#   train accuracy:		100.00 %
#   validation accuracy:		99.20 %
#   Model saved in file: ./checkpoints/model.ckpt-78
# Epoch 80 of 100 took 62.101s
#   training loss (in-iteration):		0.000180
#   train accuracy:		99.99 %
#   validation accuracy:		99.18 %
#   Model saved in file: ./checkpoints/model.ckpt-79
# Epoch 81 of 100 took 62.109s
#   training loss (in-iteration):		0.000111
#   train accuracy:		100.00 %
#   validation accuracy:		99.23 %
#   Model saved in file: ./checkpoints/model.ckpt-80
# Epoch 82 of 100 took 61.999s
#   training loss (in-iteration):		0.000059
#   train accuracy:		100.00 %
#   validation accuracy:		99.27 %
#   Model saved in file: ./checkpoints/model.ckpt-81
# Epoch 83 of 100 took 62.071s
#   training loss (in-iteration):		0.000083
#   train accuracy:		100.00 %
#   validation accuracy:		99.16 %
#   Model saved in file: ./checkpoints/model.ckpt-82
# Epoch 84 of 100 took 62.154s
#   training loss (in-iteration):		0.000108
#   train accuracy:		100.00 %
#   validation accuracy:		99.21 %
#   Model saved in file: ./checkpoints/model.ckpt-83
# Epoch 85 of 100 took 62.015s
#   training loss (in-iteration):		0.000057
#   train accuracy:		100.00 %
#   validation accuracy:		99.18 %
#   Model saved in file: ./checkpoints/model.ckpt-84
# Epoch 86 of 100 took 62.161s
#   training loss (in-iteration):		0.000042
#   train accuracy:		100.00 %
#   validation accuracy:		99.24 %
#   Model saved in file: ./checkpoints/model.ckpt-85
# Epoch 87 of 100 took 62.150s
#   training loss (in-iteration):		0.000105
#   train accuracy:		100.00 %
#   validation accuracy:		99.12 %
#   Model saved in file: ./checkpoints/model.ckpt-86
# Epoch 88 of 100 took 61.960s
#   training loss (in-iteration):		0.000217
#   train accuracy:		99.99 %
#   validation accuracy:		99.13 %
#   Model saved in file: ./checkpoints/model.ckpt-87
# Epoch 89 of 100 took 62.069s
#   training loss (in-iteration):		0.000257
#   train accuracy:		100.00 %
#   validation accuracy:		99.06 %
#   Model saved in file: ./checkpoints/model.ckpt-88
# Epoch 90 of 100 took 62.250s
#   training loss (in-iteration):		0.000155
#   train accuracy:		100.00 %
#   validation accuracy:		99.27 %
#   Model saved in file: ./checkpoints/model.ckpt-89
# Epoch 91 of 100 took 61.911s
#   training loss (in-iteration):		0.000118
#   train accuracy:		100.00 %
#   validation accuracy:		99.24 %
#   Model saved in file: ./checkpoints/model.ckpt-90
# Epoch 92 of 100 took 62.236s
#   training loss (in-iteration):		0.000128
#   train accuracy:		100.00 %
#   validation accuracy:		99.20 %
#   Model saved in file: ./checkpoints/model.ckpt-91
# Epoch 93 of 100 took 62.189s
#   training loss (in-iteration):		0.000125
#   train accuracy:		100.00 %
#   validation accuracy:		99.17 %
#   Model saved in file: ./checkpoints/model.ckpt-92
# Epoch 94 of 100 took 62.306s
#   training loss (in-iteration):		0.000095
#   train accuracy:		100.00 %
#   validation accuracy:		99.23 %
#   Model saved in file: ./checkpoints/model.ckpt-93
# Epoch 95 of 100 took 62.082s
#   training loss (in-iteration):		0.000051
#   train accuracy:		100.00 %
#   validation accuracy:		99.28 %
#   Model saved in file: ./checkpoints/model.ckpt-94
# Epoch 96 of 100 took 61.974s
#   training loss (in-iteration):		0.000172
#   train accuracy:		99.99 %
#   validation accuracy:		99.13 %
#   Model saved in file: ./checkpoints/model.ckpt-95
# Epoch 97 of 100 took 62.138s
#   training loss (in-iteration):		0.000141
#   train accuracy:		100.00 %
#   validation accuracy:		99.16 %
#   Model saved in file: ./checkpoints/model.ckpt-96
# Epoch 98 of 100 took 62.141s
#   training loss (in-iteration):		0.000089
#   train accuracy:		100.00 %
#   validation accuracy:		99.19 %
#   Model saved in file: ./checkpoints/model.ckpt-97
# Epoch 99 of 100 took 62.379s
#   training loss (in-iteration):		0.000054
#   train accuracy:		100.00 %
#   validation accuracy:		99.26 %
#   Model saved in file: ./checkpoints/model.ckpt-98
# Epoch 100 of 100 took 62.255s
#   training loss (in-iteration):		0.000085
#   train accuracy:		100.00 %
#   validation accuracy:		99.20 %
#   Model saved in file: ./checkpoints/model.ckpt-99

# %% [markdown]
# Now we can restore saved parameters:

# %%
mode=False
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    load_path = saver.restore(sess, saver.last_checkpoints[-1])
    print("Model restored from file: %s" % save_path)
    
    sess.run(tf.local_variables_initializer())
    for batch in iterate_minibatches(X_test, y_test, 500):
        inputs, targets = batch
        sess.run(update_accuracy, feed_dict={input_X: inputs, 
                                                   target_y:targets})
    test_acc = sess.run(accuracy)
    print("Final results:")
    print("  test accuracy:\t\t{:.2f} %".format(
        test_acc* 100))

    if test_acc * 100 > 99.5:
        print ("Achievement unlocked: 80lvl Warlock!")
    else:
        print ("We need more magic!")
# Out:
# W0726 15:28:55.622926 140180509525824 deprecation.py:323] From /home/yeva/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Model restored from file: ./checkpoints/model.ckpt-99
# Final results:
#   test accuracy:		99.22 %
# We need more magic!

# %% [markdown]
# # Now improve it!
#
# * Moar layers!
# * Moar units!
# * Different nonlinearities!
